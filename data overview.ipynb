# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# getting data
data = pd.read_csv('diabetic_data.csv')
id_names = pd.read_csv('IDs_mapping.csv')

# %%
# check the dimensions of the data
data.shape
# Out:
# (101766, 50)

# %%
# take a first look at the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      99493 non-null   object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    3197 non-null    object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                61510 non-null   object
#  11  medical_specialty         51817 non-null   object
#  12  num_lab_procedures        101766 non-null  int64
#  13  num_procedures            101766 non-null  int64
#  14  num_medications           101766 non-null  int64
#  15  number_outpatient         101766 non-null  int64
#  16  number_emergency          101766 non-null  int64
#  17  number_inpatient          101766 non-null  int64
#  18  diag_1                    101745 non-null  object
#  19  diag_2                    101408 non-null  object
#  20  diag_3                    100343 non-null  object
#  21  number_diagnoses          101766 non-null  int64
#  22  max_glu_serum             101766 non-null  object
#  23  A1Cresult                 101766 non-null  object
#  24  metformin                 101766 non-null  object
#  25  repaglinide               101766 non-null  object
#  26  nateglinide               101766 non-null  object
#  27  chlorpropamide            101766 non-null  object
#  28  glimepiride               101766 non-null  object
#  29  acetohexamide             101766 non-null  object
#  30  glipizide                 101766 non-null  object
#  31  glyburide                 101766 non-null  object
#  32  tolbutamide               101766 non-null  object
#  33  pioglitazone              101766 non-null  object
#  34  rosiglitazone             101766 non-null  object
#  35  acarbose                  101766 non-null  object
#  36  miglitol                  101766 non-null  object
#  37  troglitazone              101766 non-null  object
#  38  tolazamide                101766 non-null  object
#  39  examide                   101766 non-null  object
#  40  citoglipton               101766 non-null  object
#  41  insulin                   101766 non-null  object
#  42  glyburide-metformin       101766 non-null  object
#  43  glipizide-metformin       101766 non-null  object
#  44  glimepiride-pioglitazone  101766 non-null  object
#  45  metformin-rosiglitazone   101766 non-null  object
#  46  metformin-pioglitazone    101766 non-null  object
#  47  change                    101766 non-null  object
#  48  diabetesMed               101766 non-null  object
#  49  readmitted                101766 non-null  object
# dtypes: int64(13), object(37)
# memory usage: 38.8+ MB

# %%
data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
objects = ['object']

newdf = data.select_dtypes(include=numerics) # getting only numerical types
newdf_obj = data.select_dtypes(include=objects)

# %%
plt.figure(num=None, figsize=(25, 25), dpi=80, facecolor='w', edgecolor='k')

ax = sns.boxplot(x='age', y='num_lab_procedures', data=data, hue='num_procedures')

# %%
corr = newdf.corr()
plt.figure(num=None, figsize=(15, 15), dpi=80, facecolor='w', edgecolor='k')

sns.heatmap(corr)
# Out:
# <Axes: >

# %%
rmattix = newdf.corr().style.background_gradient(cmap="coolwarm")
rmattix
# Out:
# <style type="text/css">
# #T_bdc2b_row0_col0, #T_bdc2b_row1_col1, #T_bdc2b_row2_col2, #T_bdc2b_row3_col3, #T_bdc2b_row4_col4, #T_bdc2b_row5_col5, #T_bdc2b_row6_col6, #T_bdc2b_row7_col7, #T_bdc2b_row8_col8, #T_bdc2b_row9_col9, #T_bdc2b_row10_col10, #T_bdc2b_row11_col11, #T_bdc2b_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col1 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_bdc2b_row0_col2, #T_bdc2b_row0_col3, #T_bdc2b_row0_col5, #T_bdc2b_row1_col3, #T_bdc2b_row2_col0, #T_bdc2b_row2_col6, #T_bdc2b_row2_col12, #T_bdc2b_row3_col1, #T_bdc2b_row4_col7, #T_bdc2b_row4_col8, #T_bdc2b_row7_col4, #T_bdc2b_row7_col9, #T_bdc2b_row7_col10, #T_bdc2b_row7_col11 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col4, #T_bdc2b_row3_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col6, #T_bdc2b_row11_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col7, #T_bdc2b_row1_col7, #T_bdc2b_row7_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col8, #T_bdc2b_row7_col0, #T_bdc2b_row8_col11, #T_bdc2b_row9_col10, #T_bdc2b_row10_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col9, #T_bdc2b_row1_col2, #T_bdc2b_row1_col9, #T_bdc2b_row2_col8, #T_bdc2b_row5_col2, #T_bdc2b_row11_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col10, #T_bdc2b_row6_col0, #T_bdc2b_row10_col9, #T_bdc2b_row12_col9 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col11, #T_bdc2b_row1_col4, #T_bdc2b_row4_col1, #T_bdc2b_row12_col10 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_bdc2b_row0_col12 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_bdc2b_row1_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_bdc2b_row1_col5, #T_bdc2b_row12_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_bdc2b_row1_col6, #T_bdc2b_row8_col1, #T_bdc2b_row11_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_bdc2b_row1_col8, #T_bdc2b_row1_col11, #T_bdc2b_row8_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_bdc2b_row1_col10, #T_bdc2b_row4_col10, #T_bdc2b_row4_col11, #T_bdc2b_row9_col7, #T_bdc2b_row9_col8 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_bdc2b_row1_col12, #T_bdc2b_row6_col8 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_bdc2b_row2_col1, #T_bdc2b_row5_col4, #T_bdc2b_row9_col3, #T_bdc2b_row11_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_bdc2b_row2_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_bdc2b_row2_col4, #T_bdc2b_row3_col5, #T_bdc2b_row9_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_bdc2b_row2_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_bdc2b_row2_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_bdc2b_row2_col9, #T_bdc2b_row8_col10, #T_bdc2b_row9_col5, #T_bdc2b_row10_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_bdc2b_row2_col10, #T_bdc2b_row3_col9, #T_bdc2b_row6_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_bdc2b_row2_col11 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_bdc2b_row3_col2, #T_bdc2b_row10_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_bdc2b_row3_col4, #T_bdc2b_row3_col7, #T_bdc2b_row4_col3, #T_bdc2b_row6_col1, #T_bdc2b_row7_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_bdc2b_row3_col6, #T_bdc2b_row3_col12 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_bdc2b_row3_col8, #T_bdc2b_row10_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_bdc2b_row3_col10, #T_bdc2b_row5_col9, #T_bdc2b_row6_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_bdc2b_row3_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_bdc2b_row4_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_bdc2b_row4_col2, #T_bdc2b_row9_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_bdc2b_row4_col5, #T_bdc2b_row4_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_bdc2b_row4_col6, #T_bdc2b_row4_col12, #T_bdc2b_row6_col7, #T_bdc2b_row7_col12 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_bdc2b_row5_col0, #T_bdc2b_row10_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_bdc2b_row5_col1, #T_bdc2b_row6_col11, #T_bdc2b_row10_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_bdc2b_row5_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_bdc2b_row5_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_bdc2b_row5_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_bdc2b_row5_col8 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_bdc2b_row5_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_bdc2b_row5_col11, #T_bdc2b_row11_col1, #T_bdc2b_row11_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_bdc2b_row5_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_bdc2b_row6_col3, #T_bdc2b_row9_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_bdc2b_row6_col4, #T_bdc2b_row9_col11, #T_bdc2b_row11_col0, #T_bdc2b_row12_col3, #T_bdc2b_row12_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_bdc2b_row6_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_bdc2b_row6_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_bdc2b_row6_col12, #T_bdc2b_row7_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_bdc2b_row7_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_bdc2b_row7_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_bdc2b_row7_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_bdc2b_row8_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_bdc2b_row8_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_bdc2b_row8_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_bdc2b_row8_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_bdc2b_row8_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_bdc2b_row8_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_bdc2b_row8_col9 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_bdc2b_row8_col12 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_bdc2b_row9_col2, #T_bdc2b_row11_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_bdc2b_row9_col6, #T_bdc2b_row10_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_bdc2b_row9_col12 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_bdc2b_row10_col1, #T_bdc2b_row10_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_bdc2b_row10_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_bdc2b_row10_col11 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_bdc2b_row11_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_bdc2b_row11_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_bdc2b_row11_col10 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_bdc2b_row11_col12 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_bdc2b_row12_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_bdc2b_row12_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_bdc2b_row12_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_bdc2b_row12_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_bdc2b_row12_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_bdc2b_row12_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_bdc2b_row12_col8 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# </style>
# <table id="T_bdc2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdc2b_level0_col0" class="col_heading level0 col0" >encounter_id</th>
#       <th id="T_bdc2b_level0_col1" class="col_heading level0 col1" >patient_nbr</th>
#       <th id="T_bdc2b_level0_col2" class="col_heading level0 col2" >admission_type_id</th>
#       <th id="T_bdc2b_level0_col3" class="col_heading level0 col3" >discharge_disposition_id</th>
#       <th id="T_bdc2b_level0_col4" class="col_heading level0 col4" >admission_source_id</th>
#       <th id="T_bdc2b_level0_col5" class="col_heading level0 col5" >time_in_hospital</th>
#       <th id="T_bdc2b_level0_col

# %%
plt.figure(num=None, figsize=(15, 15), dpi=80, facecolor='w', edgecolor='k')


sns.relplot(x="time_in_hospital", y="num_medications", hue='num_lab_procedures', col='gender', 
            row='num_procedures',
            data=data)
plt.show();

# %%
from scipy.stats import norm

sns.distplot(data['admission_type_id'], fit=norm, kde=False)
# Out:
# C:\Users\nishk\AppData\Local\Temp\ipykernel_9020\2439102399.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['admission_type_id'], fit=norm, kde=False)
# <Axes: xlabel='admission_type_id'>

# %%
sns.displot(data['discharge_disposition_id'])
